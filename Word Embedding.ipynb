# %% [markdown]
# ### Word Embedding Techniques using Embedding Layers in Keras

# %% [raw]
# Steps To  Follow
#
#
# 1. Sentences
# 2. One hot Representation-- index from the dic
# 3. Onhot Repre---> Embeddind Layer Keras
# To form Embedding matrix
# 4. Embedding matrix

# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
## sentences
sent = [
    'the glass of tea',
    'the glass of milk',
    'I am a good boy',
    'I am a good developer',
    'understand the meaning of work',
    'king is not poor'
]

# %%
sent
# Out:
# ['the glass of tea',
#  'the glass of milk',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of work',
#  'king is not poor']

# %%
## vocabulary size
voc_size = 10000

# %% [markdown]
# ### One Hot Representation

# %%
one_hot_repr = [one_hot(words,voc_size) for words in sent]
print(one_hot_repr)
# Out:
# [[7517, 5240, 1938, 8141], [7517, 5240, 1938, 4234], [4366, 3375, 1859, 3926, 972], [4366, 3375, 1859, 3926, 8071], [1021, 7517, 3386, 1938, 3801], [8599, 3893, 178, 7541]]

# %% [markdown]
# ### Word Embedding Representation

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
## adding padding to the one-hot embedding
sent_length=8
embedded_docs = pad_sequences(one_hot_repr, padding='pre', maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 7517 5240 1938 8141]
#  [   0    0    0    0 7517 5240 1938 4234]
#  [   0    0    0 4366 3375 1859 3926  972]
#  [   0    0    0 4366 3375 1859 3926 8071]
#  [   0    0    0 1021 7517 3386 1938 3801]
#  [   0    0    0    0 8599 3893  178 7541]]

# %%
dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size, dim, input_length=sent_length))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 8, 10)             100000
# =================================================================
# Total params: 100,000
# Trainable params: 100,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(model.predict(embedded_docs))
# Out:
# [[[-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [ 0.01172306  0.00328093 -0.03564436  0.00923502 -0.04707932
#     0.02555976 -0.00678955  0.00647219  0.04087794 -0.00232433]
#   [ 0.04883796  0.03918253 -0.0395037   0.00737399  0.03266025
#    -0.00896648 -0.00986991 -0.00872814  0.04745665  0.03232664]
#   [-0.03391016  0.00794322 -0.04591559 -0.0034533   0.01801318
#     0.00038097 -0.01386524  0.0447487   0.03609313 -0.04877665]
#   [-0.04675622 -0.00449618  0.03596831 -0.00319067  0.03268057
#    -0.03331033 -0.03510378 -0.03914671  0.03363978 -0.00565875]]
#
#  [[-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [ 0.01172306  0.00328093 -0.03564436  0.00923502 -0.04707932
#     0.02555976 -0.00678955  0.00647219  0.04087794 -0.00232433]
#   [ 0.04883796  0.03918253 -0.0395037   0.00737399  0.03266025
#    -0.00896648 -0.00986991 -0.00872814  0.04745665  0.03232664]
#   [-0.03391016  0.00794322 -0.04591559 -0.0034533   0.01801318
#     0.00038097 -0.01386524  0.0447487   0.03609313 -0.04877665]
#   [ 0.00152816  0.00238261  0.04692582 -0.03229947  0.03805602
#     0.01670959  0.00435491 -0.04941069  0.02478874 -0.02812188]]
#
#  [[-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [ 0.00880077 -0.04846202  0.03657964 -0.00171162  0.0056973
#     0.00455987  0.01777787 -0.01836096 -0.01159469  0.02673067]
#   [ 0.0077343   0.00147726  0.00178541  0.01986054  0.03484942
#    -0.02992839 -0.02161212 -0.00363711 -0.02779694 -0.04999845]
#   [ 0.02010175 -0.0024654   0.03326074  0.03653315  0.03385154
#    -0.0259546  -0.03209304 -0.0212091  -0.01470749  0.03118205]
#   [ 0.02922248 -0.04136766 -0.02663131  0.02486129  0.03124804
#    -0.02362964 -0.02357128 -0.0298691   0.02122265 -0.03625403]
#   [ 0.02030836  0.0167062  -0.01734876 -0.00267236  0.03904695
#    -0.03866738  0.02890242  0.03776529  0.03226242 -0.02082483]]
#
#  [[-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [ 0.00880077 -0.04846202  0.03657964 -0.00171162  0.0056973
#     0.00455987  0.01777787 -0.01836096 -0.01159469  0.02673067]
#   [ 0.0077343   0.00147726  0.00178541  0.01986054  0.03484942
#    -0.02992839 -0.02161212 -0.00363711 -0.02779694 -0.04999845]
#   [ 0.02010175 -0.0024654   0.03326074  0.03653315  0.03385154
#    -0.0259546  -0.03209304 -0.0212091  -0.01470749  0.03118205]
#   [ 0.02922248 -0.04136766 -0.02663131  0.02486129  0.03124804
#    -0.02362964 -0.02357128 -0.0298691   0.02122265 -0.03625403]
#   [ 0.00897359 -0.00856621 -0.04703787 -0.00054055 -0.00081543
#    -0.01944734  0.00853579  0.01813153 -0.00085138  0.0041224 ]]
#
#  [[-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [-0.02024942 -0.01042504  0.01628956  0.01246461 -0.01124133
#     0.03196556  0.02763777  0.01156076  0.04155585 -0.00034384]
#   [ 0.01172306  0.00328093 -0.03564436  0.00923502 -0.04707932
#     0.02555976 -0.00678955  0.00647219  0.04087794 -0.00232433]
#   [-0.00739365 -0.03340311  0.00590923 -0.0017585  -0.03477087
#     0.0425286  -0.0476422  -0.0485144  -0.03468765  0.0303344 ]
#   [-0.03391016  0.00794322 -0.04591559 -0.0034533   0.01801318
#     0.00038097 -0.01386524  0.0447487   0.03609313 -0.04877665]
#   [-0.04114221  0.03442482 -0.02195872  0.03033667  0.00879202
#     0.01726953 -0.03265126  0.0095439   0.03768991  0.02923268]]
#
#  [[-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123
#     0.02098389 -0.00743326  0.02181137  0.00641491  0.00676714]
#   [ 0.04385264 -0.00497165 -0.04217779 -0.02658316 -0.03283267
#     0.01482798  0.04429844  0.01996006  0.0211499  -0.04296501]
#   [-0.00215924  0.01519779  0.02286322  0.02624008  0.04308486
#    -0.01102442  0.02125516 -0.0332367   0.0179381   0.03164071]
#   [-0.0038983  -0.02741222 -0.00018264  0.02335027 -0.0209986
#    -0.04538006 -0.04505995  0.01853294  0.00826268 -0.00826769]
#   [-0.04357574 -0.02109175  0.00029347  0.03063491  0.02642724
#    -0.04737243  0.04589993  0.03097209 -0.02541016 -0.0070814 ]]]

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 7517, 5240, 1938, 8141])

# %%
print(model.predict(embedded_docs)[0])
# Out:
# [[-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123  0.02098389
#   -0.00743326  0.02181137  0.00641491  0.00676714]
#  [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123  0.02098389
#   -0.00743326  0.02181137  0.00641491  0.00676714]
#  [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123  0.02098389
#   -0.00743326  0.02181137  0.00641491  0.00676714]
#  [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123  0.02098389
#   -0.00743326  0.02181137  0.00641491  0.00676714]
#  [ 0.01172306  0.00328093 -0.03564436  0.00923502 -0.04707932  0.02555976
#   -0.00678955  0.00647219  0.04087794 -0.00232433]
#  [ 0.04883796  0.03918253 -0.0395037   0.00737399  0.03266025 -0.00896648
#   -0.00986991 -0.00872814  0.04745665  0.03232664]
#  [-0.03391016  0.00794322 -0.04591559 -0.0034533   0.01801318  0.00038097
#   -0.01386524  0.0447487   0.03609313 -0.04877665]
#  [-0.04675622 -0.00449618  0.03596831 -0.00319067  0.03268057 -0.03331033
#   -0.03510378 -0.03914671  0.03363978 -0.00565875]]

# %%
print(model.predict(embedded_docs)[0])
# Out:
# [[-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123  0.02098389
#   -0.00743326  0.02181137  0.00641491  0.00676714]
#  [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123  0.02098389
#   -0.00743326  0.02181137  0.00641491  0.00676714]
#  [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123  0.02098389
#   -0.00743326  0.02181137  0.00641491  0.00676714]
#  [-0.04108484 -0.04218247  0.00765065  0.04972715  0.01062123  0.02098389
#   -0.00743326  0.02181137  0.00641491  0.00676714]
#  [ 0.01172306  0.00328093 -0.03564436  0.00923502 -0.04707932  0.02555976
#   -0.00678955  0.00647219  0.04087794 -0.00232433]
#  [ 0.04883796  0.03918253 -0.0395037   0.00737399  0.03266025 -0.00896648
#   -0.00986991 -0.00872814  0.04745665  0.03232664]
#  [-0.03391016  0.00794322 -0.04591559 -0.0034533   0.01801318  0.00038097
#   -0.01386524  0.0447487   0.03609313 -0.04877665]
#  [-0.04675622 -0.00449618  0.03596831 -0.00319067  0.03268057 -0.03331033
#   -0.03510378 -0.03914671  0.03363978 -0.00565875]]

# %% [markdown]
# This list is the word embedding of the first line -> 'the glass of tea' into list of 10 dimensions.
# The first four list of this will be same because the value of the first 4 content is 0.

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
vec1 = [model.predict(embedded_docs)[0][-1]]  #tea
vec2 = [model.predict(embedded_docs)[1][-1]]  #milk

# %%
## cosine similarity between milk and tea
cosine_similarity(vec1,vec2)
# Out:
# array([[0.5605608]], dtype=float32)

# %%
## choosing same word from the list => 'the'
vec1 = [model.predict(embedded_docs)[0][0]]
vec2 = [model.predict(embedded_docs)[1][0]]

# %%
cosine_similarity(vec1,vec2)
# Out:
# array([[1.]], dtype=float32)
